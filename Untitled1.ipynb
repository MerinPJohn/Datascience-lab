# %% [markdown]
# <a href="https://colab.research.google.com/github/MerinPJohn/Datascience-lab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange (0,3*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,3*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.plot(x,y_sin)
plt.plot(x,y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title("Sine and Cosine")
plt.legend(['Sine','Cosine'])
plt.show()

# %%
#subplots
import numpy as np
import matplotlib pyplot as plt
x=np.arange(0,3*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.subplt(2,1,1)
plt.plot(x,y_sin)
plt.title('sine')
plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('cosine')
plt.show()
# Out:
#   File "<ipython-input-3-1c3600c48eca>", line 3
#     import matplotlib pyplot as plt
#                       ^
# SyntaxError: invalid syntax

# %%
#subplots
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,3*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.subplt(2,1,1)
plt.plot(x,y_sin)
plt.title('sine')
plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('cosine')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-97aa0f35abfb> in <cell line: 7>()
#       5 y_sin=np.sin(x)
#       6 y_cos=np.cos(x)
# ----> 7 plt.subplt(2,1,1)
#       8 plt.plot(x,y_sin)
#       9 plt.title('sine')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subplt'

# %%
#subplots
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,3*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.subplot(2,1,1)
plt.plot(x,y_sin)
plt.title('sine')
plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('cosine')
plt.show()
